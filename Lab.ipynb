# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

data = pd.read_csv("student_data.csv")

X = data.drop("passed", axis=1)
y = data["passed"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# Accuracy: 1.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

data = pd.read_csv("student_data.csv")


X = data.drop("passed", axis=1)
y = data["passed"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


model = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# Accuracy: 1.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC

df=pd.read_csv("student_data.csv")

x=df.drop("passed",axis=1)
y=df["passed"]

x_train,x_test,y_train,y_test=train_test_split(x,y)

model=LinearSVC()
model.fit(x_train,y_train)

prediction=model.predict(x_test)

print("Accuracy:",model.score(x_test,y_test))
# Out:
# Accuracy: 0.75

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

data = pd.read_csv("diabetes.csv")

X = data.drop("Outcome", axis=1)
y = data["Outcome"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# Accuracy: 0.53125

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC

data = pd.read_csv("diabetes.csv")

X = data.drop("Outcome", axis=1)
y = data["Outcome"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearSVC(max_iter=10000)
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# Accuracy: 0.5066287878787878

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

data = pd.read_csv("diabetes.csv")

X = data.drop("Outcome", axis=1)
y = data["Outcome"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = KNeighborsClassifier(max_iter=10000)
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       8 y = data["Outcome"]
#      10 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# ---> 12 model = KNeighborsClassifier(max_iter=10000)
#      13 model.fit(X_train, y_train)
#      15 predictions = model.predict(X_test)
#
# TypeError: KNeighborsClassifier.__init__() got an unexpected keyword argument 'max_iter'

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = np.array([[2,40],[4,50],[6,60],[8,70],[10,80]])
y = np.array([35,45,55,65,80])  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict([[7,65]])
print("Predicted Marks:", pred)
# Out:
# Predicted Marks: [60.]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X = np.array([[2,40],[4,50],[6,60],[8,70],[10,80]])
y = np.array([0,1,1,1,1])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)

pred = model.predict([[5,55]])
print("Pass/Fail:", pred)
# Out:
# Pass/Fail: [1]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

X = np.array([[2,40],[3,45],[4,50],[6,60],[8,70],[10,80]])
y = np.array([0,0,0,1,1,1]) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)

pred = model.predict([[3,40]])
print("Pass/Fail:", pred)
# Out:
# Pass/Fail: [0]
